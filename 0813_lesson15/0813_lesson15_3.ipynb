# %%
#1家分站30天的營收
import numpy as np
one_store = np.random.randint(100,10000,size=(30,))
one_store
# Out:
# array([8868, 4072, 6415, 4558, 6827, 5744, 2007, 5312, 6799, 2436, 9540,
#        6629, 8706, 1623, 9344, 1791,  950, 5674, 8359, 8305, 3595, 1143,
#        2427, 9571, 8623,  673, 6586, 5813, 4280,  603], dtype=int32)

# %%
#累計每天這家店的營收
oneStoreCum = one_store.cumsum()
oneStoreCum
# Out:
# array([  8868,  12940,  19355,  23913,  30740,  36484,  38491,  43803,
#         50602,  53038,  62578,  69207,  77913,  79536,  88880,  90671,
#         91621,  97295, 105654, 113959, 117554, 118697, 121124, 130695,
#        139318, 139991, 146577, 152390, 156670, 157273])

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(111)
axes.plot(range(1, 31), oneStoreCum, marker='o', linestyle='-', color='r', label='Cumulative Revenue')
axes.set_title('Cumulative Revenue Over Time')
axes.set_xlabel('Days')
axes.set_ylabel('Revenue')
axes.legend()
axes.grid()
plt.show()
